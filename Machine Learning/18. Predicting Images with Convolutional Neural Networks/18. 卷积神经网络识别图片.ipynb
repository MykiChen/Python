# %%
import requests

res = requests.get('https://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&ct=201326592&is=&fp=result&queryWord=%E6%9E%97%E5%BF%97%E7%8E%B2&cl=2&lm=-1&ie=utf-8&oe=utf-8&adpicid=&st=-1&z=&ic=&hd=&latest=&copyright=&word=%E6%9E%97%E5%BF%97%E7%8E%B2&s=&se=&tab=&width=&height=&face=0&istype=2&qc=&nc=1&fr=&expermode=&force=&cg=star&pn=30&rn=30&gsm=&1578807000105=')
res.encoding='utf-8'

# %%
for rec in res.json()['data']:
    print(rec.get('thumbURL'))
# Out:
# https://ss1.bdstatic.com/70cFvXSh_Q1YnxGkpoWK1HF6hhy/it/u=2722094404,2703344803&fm=26&gp=0.jpg
# https://ss0.bdstatic.com/70cFuHSh_Q1YnxGkpoWK1HF6hhy/it/u=1482585928,3504071248&fm=26&gp=0.jpg
# https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=3869864981,1202018795&fm=26&gp=0.jpg
# https://ss1.bdstatic.com/70cFuXSh_Q1YnxGkpoWK1HF6hhy/it/u=2430963130,3684212189&fm=26&gp=0.jpg
# https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=2459053419,3261532264&fm=26&gp=0.jpg
# https://ss1.bdstatic.com/70cFuXSh_Q1YnxGkpoWK1HF6hhy/it/u=1352404826,2664140643&fm=26&gp=0.jpg
# https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=1444135843,4234544580&fm=26&gp=0.jpg
# https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=2633686884,3160662526&fm=26&gp=0.jpg
# https://ss1.bdstatic.com/70cFvXSh_Q1YnxGkpoWK1HF6hhy/it/u=2991437967,1899089252&fm=26&gp=0.jpg
# https://ss0.bdstatic.com/70cFuHSh_Q1YnxGkpoWK1HF6hhy/it/u=1046853570,880991344&fm=26&gp=0.jpg
# ...

# %%
len(res.json()['data'])
# Out:
# 31

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}

with open('1.jpg', 'wb') as f:
    res2 = requests.get('https://ss1.bdstatic.com/70cFvXSh_Q1YnxGkpoWK1HF6hhy/it/u=2400131971,2942168080&fm=26&gp=0.jpg', headers = headers)
    f.write(res2.content)

# %%
from PIL import Image

#Image.open('1.jpg')
Image.open('test/u=1548044685,853025122&fm=26&gp=0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x600 at 0x10BB1CFD0>

# %%
# https://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&ct=201326592&is=&fp=result&queryWord=%E6%9E%97%E5%BF%97%E7%8E%B2&cl=2&lm=-1&ie=utf-8&oe=utf-8&adpicid=&st=-1&z=&ic=&hd=&latest=&copyright=&word=%E6%9E%97%E5%BF%97%E7%8E%B2&s=&se=&tab=&width=&height=&face=0&istype=2&qc=&nc=1&fr=&expermode=&force=&cg=star&pn=30&rn=30&gsm=&1578807000105=
# https://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&ct=201326592&is=&fp=result&queryWord=%E6%9E%97%E5%BF%97%E7%8E%B2&cl=2&lm=-1&ie=utf-8&oe=utf-8&adpicid=&st=-1&z=&ic=&hd=&latest=&copyright=&word=%E6%9E%97%E5%BF%97%E7%8E%B2&s=&se=&tab=&width=&height=&face=0&istype=2&qc=&nc=1&fr=&expermode=&force=&cg=star&pn=60&rn=30&gsm=&1578807000428=

# %%
url = 'https://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&ct=201326592&is=&fp=result&queryWord={0}&cl=2&lm=-1&ie=utf-8&oe=utf-8&adpicid=&st=-1&z=&ic=&hd=&latest=&copyright=&word={0}&s=&se=&tab=&width=&height=&face=0&istype=2&qc=&nc=1&fr=&expermode=&force=&cg=star&pn={1}&rn=30&gsm=&1578807000105='
from urllib import parse

k = parse.quote('范冰冰')
apiurl = url.format(k, 30)

# %%
res = requests.get(apiurl)
res.encoding = 'utf-8'
#res.json()

# %% [markdown]
# # 构造获取图片函数

# %%
import requests
import os
from urllib import parse

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}
img_url = 'https://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&ct=201326592&is=&fp=result&queryWord={0}&cl=2&lm=-1&ie=utf-8&oe=utf-8&adpicid=&st=-1&z=&ic=&hd=&latest=&copyright=&word={0}&s=&se=&tab=&width=&height=&face=0&istype=2&qc=&nc=1&fr=&expermode=&force=&cg=star&pn={1}&rn=30&gsm=&1578807000105='

def getIdolPicture(keyword, dest_dir, batch):
    # 建立图片储存路径
    if not os.path.exists(dest_dir):
        os.mkdir(dest_dir)
        
    for i in range(batch):
        res = requests.get(img_url.format(parse.quote(keyword), i*30))
        res.encoding = 'utf-8'
        print(len(res.json()['data']))
        for ele in res.json()['data']:
            url = ele.get('thumbURL')
            if url:
                # 获取图片链接最后部分并做为图片名字
                with open(dest_dir + url.split('/')[-1], 'wb') as f:
                    res2 = requests.get(url, headers=headers)
                    f.write(res2.content)

# %%
getIdolPicture('范冰冰', 'test/', 2)
# Out:
# 31
# 31
