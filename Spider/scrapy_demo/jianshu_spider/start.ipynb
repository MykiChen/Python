# %%
from scrapy import cmdline

cmdline.execute("scrapy crawl js".split())
# Out:
# 2019-12-28 15:21:47 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: jianshu_spider)
# 2019-12-28 15:21:47 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.4 (default, Aug 13 2019, 15:17:50) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.7, Platform Darwin-19.2.0-x86_64-i386-64bit
# 2019-12-28 15:21:47 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'jianshu_spider', 'NEWSPIDER_MODULE': 'jianshu_spider.spiders', 'SPIDER_MODULES': ['jianshu_spider.spiders']}
# 2019-12-28 15:21:47 [scrapy.extensions.telnet] INFO: Telnet Password: 2678bfe2f8b07f11
# 2019-12-28 15:21:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...
