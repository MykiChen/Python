# %%
from scrapy import cmdline

cmdline.execute("scrapy crawl sfw".split())
# Out:
# 2019-12-29 00:20:20 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: fang)
# 2019-12-29 00:20:20 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.4 (default, Aug 13 2019, 15:17:50) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.7, Platform Darwin-19.2.0-x86_64-i386-64bit
# 2019-12-29 00:20:20 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'fang', 'DOWNLOAD_DELAY': 1, 'NEWSPIDER_MODULE': 'fang.spiders', 'SPIDER_MODULES': ['fang.spiders']}
# 2019-12-29 00:20:20 [scrapy.extensions.telnet] INFO: Telnet Password: 1d2502d79150db82
# 2019-12-29 00:20:20 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...
