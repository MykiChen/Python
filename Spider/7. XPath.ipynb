# %%
from lxml import etree

# %%
text = """
<div class="list_item_top">
            <div class="position">
                <div class="p_top">
                    <a class="position_link" href="https://www.lagou.com/jobs/2483626.html?show=0fefd3d3035c4df1b3493dae4f5fe5ba" target="_blank" data-index="0" data-lg-tj-id="8E00" data-lg-tj-no="
                
                    
                    0101
                    
                
                " data-lg-tj-cid="2483626" data-lg-tj-abt="dm-csearch-experimentalPositionStrategy|0" data-lg-webtj-_show_id="0fefd3d3035c4df1b3493dae4f5fe5ba" data-lg-webtj-_search_type="csearch" data-lg-webtj-_content_type="jd">
                        <h3 style="max-width: 180px;">Python</h3>
                        
                            
                                
                                    <span class="add">[<em>北京·北京大…</em>]</span>
                                
                            
                        

                    </a>
                    <span class="format-time">10:33发布</span>
                    
                        
                    
                        
                    
                        
                            <input type="hidden" class="hr_portrait" value="i/image/M00/72/82/Cgp3O1gscBCAaqDmAAD5uLM-F-s75.jpeg">
                            <input type="hidden" class="hr_name" value="Vikki">
                            <input type="hidden" class="hr_position" value="HRD">
                            <input type="hidden" class="target_hr" value="462992">
                            <input type="hidden" class="target_position" value="2483626">
                            
                            <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0101" data-lg-tj-cid="31395" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"></div>
                            
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                        
                    
                </div>
                <div class="p_bot">
                    <div class="li_b_l">
                        <span class="money">13k-25k</span>
                        <!--<i></i>-->经验不限 / 本科
                    </div>
                </div>
            </div>
            <div class="company">
                <div class="company_name">
                    <a href="https://www.lagou.com/gongsi/31395.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="
                
                    
                    0101
                    
                
                " data-lg-tj-cid="31395" data-lg-tj-abt="dm-csearch-experimentalPositionStrategy|0">灵雀云</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>
                </div>
                <div class="industry">
                    数据服务,企业服务 / B轮 / 150-500人
                </div>
            </div>
            <div class="com_logo">
                <a href="https://www.lagou.com/gongsi/31395.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="
                
                    
                    0101
                    
                
                " data-lg-tj-cid="31395" data-lg-tj-abt="dm-csearch-experimentalPositionStrategy|0">
                    
                    <img src="//www.lgstatic.com/thumbnail_120x120/image1/M00/00/47/CgYXBlTUXOSAF2BxAABArVeLFCY330.png" alt="灵雀云" width="60" height="60">
                    
                </a>
            </div>
        </div>
"""


def parse_text():
    htmlElement = etree.HTML(text)
    print(etree.tostring(htmlElement, encoding = 'utf-8').decode('utf-8'))
          
def parse_file():
    htmlElement = etree.parse(text)
    print(etree.tostring(htmlElement, encoding = 'utf-8').decode('utf-8'))
    
    
def 

if __name__ == '__main__':
    parse_file()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-76a6f04eb97b> in <module>
#     110
#     111 if __name__ == '__main__':
# --> 112     parse_file()
#
# <ipython-input-22-76a6f04eb97b> in parse_file()
#     105
#     106 def parse_file():
# --> 107     htmlElement = etree.parse(text)
#     108     print(etree.tostring(htmlElement, encoding = 'utf-8').decode('utf-8'))
#     109
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError()
#
# ...
