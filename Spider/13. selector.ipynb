# %%
from bs4 import BeautifulSoup

# %%
html = """
<div data-v-7e6dc93e="" class="main max-center g-clr">
<a href="www.utas.edu.au">UTAS</a>
<div data-v-7e6dc93e="" class="search-sidebar"><div data-v-7e6dc93e="" class="sidebar-title">Filter by</div> <div data-v-7e6dc93e="" class="option-wrapper"><div data-v-7e6dc93e="" class="option-item"><div data-v-7e6dc93e="" class="item-text"><a data-v-7e6dc93e="" href="javascript:;" class="item-link">Country/region</a> <div data-v-7e6dc93e="" class="open-btn"><div data-v-7e6dc93e="" class="vertical-btn"></div> <div data-v-7e6dc93e="" class="transverse-btn"></div></div></div> <ul data-v-7e6dc93e="" class="item-ul" style="padding-top: 20px; display: none;"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">China</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">USA</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Netherlands</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Germany</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Korea</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Japan</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">India</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Thailand</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Malaysia</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Singapore</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">United Kingdom</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Italy</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Indonesia</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Brazil</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Australia</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Philippines</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">South Africa</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Vietnam</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">The United Arab Emirates</div></div></li></ul></div> <div data-v-7e6dc93e="" class="option-item"><div data-v-7e6dc93e="" class="item-text"><a data-v-7e6dc93e="" href="javascript:;" class="item-link">City</a> <div data-v-7e6dc93e="" class="open-btn"><div data-v-7e6dc93e="" class="vertical-btn"></div> <div data-v-7e6dc93e="" class="transverse-btn"></div></div></div> <div data-v-7e6dc93e="" class="current-selection" style="padding-top: 20px; display: none;"><div data-v-7e6dc93e="" class="search-input"><input data-v-7e6dc93e="" maxlength="20" type="text" class="item-link search"> <!----> <i data-v-7e6dc93e="" class="search-icon"></i></div> <p data-v-7e6dc93e="" class="tips" style="display: none;">Showing 76 results for ""</p> <p data-v-7e6dc93e="" class="tips active">&nbsp;</p> <ul data-v-7e6dc93e="" class="city-selection"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Shenzhen</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Beijing</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Guangzhou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Shanghai</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Chengdu</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Wuhan</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Hong Kong(China)</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Taiwan(China)</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Changsha</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Chongqing</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Tianjin</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Changchun</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Dalian</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Fuzhou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Guiyang</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Harbin</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Hangzhou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Hefei</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Hohhot</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Jinan</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Kunming</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Lanzhou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Nanning</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Nanchang</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Nanjing</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Shenyang</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Shijiazhuang</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Taiyuan</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Urumchi</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Xi'an</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Xining</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Xiamen</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Zhengzhou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Qingdao</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Wuxi</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Yantai</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Suzhou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Haikou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Zibo</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Ningbo</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Yinchuan</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Yangzhou</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Shanwei</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Shunde</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Guilin</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Macau(China)</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Zhuhai</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Guian</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Foshan</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Baoding</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Xiong'an New Area</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Nantong</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Lhasa</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Chengmai County</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Huoerguosi</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Palo Alto</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">New York</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Seattle</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Los Angeles</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Amsterdam</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Frankfurt</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Seoul</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Tokyo</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Bangalore</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li"> Bangkok</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Kuala Lumpur</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Singapore</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">London</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Milan</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Jakarta</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Brasilia</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Canberra</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Manila</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Tswane</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Hanoi</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Dubai</div></div></li></ul></div></div> <div data-v-7e6dc93e="" class="option-item"><div data-v-7e6dc93e="" class="item-text active"><a data-v-7e6dc93e="" href="javascript:;" class="item-link">Job category</a> <div data-v-7e6dc93e="" class="open-btn"><div data-v-7e6dc93e="" class="vertical-btn"></div> <div data-v-7e6dc93e="" class="transverse-btn"></div></div></div> <ul data-v-7e6dc93e="" class="item-ul" style="padding-top: 20px;"><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category active"><div data-v-7e6dc93e="" class="classification-text">Technology</div></div> <div data-v-7e6dc93e="" class="classification-item technology-item"><ul data-v-7e6dc93e="" class="second-menu"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li active">Software Engineering</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li active">Quality Control</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li active">Technology Operations</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li active">Security</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li active">AI,Algorithm and Big Data</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li active">Enterprise Management</div></div></li></ul></div></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Design &amp; Art</div></div> <div data-v-7e6dc93e="" class="classification-item technology-item"><ul data-v-7e6dc93e="" class="second-menu"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Design</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Game Art</div></div></li></ul></div></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Product</div></div> <div data-v-7e6dc93e="" class="classification-item technology-item"><ul data-v-7e6dc93e="" class="second-menu"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Product Design and Operations</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Game Design and Operations</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Project Management</div></div></li></ul></div></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Marketing &amp; Public Relations</div></div> <!----></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Sales，Service &amp; Support</div></div> <div data-v-7e6dc93e="" class="classification-item technology-item"><ul data-v-7e6dc93e="" class="second-menu"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Sales</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Customer Support</div></div></li></ul></div></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Content </div></div> <!----></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Finance</div></div> <!----></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Human Resources</div></div> <!----></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Legal</div></div> <!----></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Administration</div></div> <!----></li><li data-v-7e6dc93e="" class="classification technology"><div data-v-7e6dc93e="" class="item-li technology-category"><div data-v-7e6dc93e="" class="classification-text">Strategy &amp; Investment</div></div> <!----></li></ul></div> <div data-v-7e6dc93e="" class="option-item"><div data-v-7e6dc93e="" class="item-text"><a data-v-7e6dc93e="" href="javascript:;" class="item-link">Business group</a> <div data-v-7e6dc93e="" class="open-btn"><div data-v-7e6dc93e="" class="vertical-btn"></div> <div data-v-7e6dc93e="" class="transverse-btn"></div></div></div> <ul data-v-7e6dc93e="" class="item-ul" style="padding-top: 20px; display: none;"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">CDG</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">CSIG</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">IEG</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">PCG</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">WXG</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">TEG</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">S1</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">S2</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">S3</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">TME</div></div></li></ul></div> <div data-v-7e6dc93e="" class="option-item last"><div data-v-7e6dc93e="" class="item-text"><a data-v-7e6dc93e="" href="javascript:;" class="item-link">Recruitment type</a> <div data-v-7e6dc93e="" class="open-btn"><div data-v-7e6dc93e="" class="vertical-btn"></div> <div data-v-7e6dc93e="" class="transverse-btn"></div></div></div> <ul data-v-7e6dc93e="" class="item-ul" style="padding-top: 20px; display: none;"><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Experienced Hires</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Campus Recruitment-graduate</div></div></li><li data-v-7e6dc93e="" class="item-li-box"><div data-v-7e6dc93e="" class="checkbox-content"><div data-v-7e6dc93e="" class="item-li">Campus Recruitment-intern</div></div></li></ul></div></div></div> <div data-v-7e6dc93e="" class="search-content"><div data-v-7e6dc93e="" class="search-nav g-clr"><div data-v-7e6dc93e="" class="new">Most recent</div> <div data-v-7e6dc93e="" class="search-number"><div data-v-7e6dc93e="" class="search-count">Showing 1-10 of 1931 jobs</div></div></div> <div data-v-7e6dc93e="" class="label-wrapper default" style="max-height: 58px;"><div data-v-7e6dc93e="" class="btn remove-label">Reset</div> <div data-v-7e6dc93e="" class="btn more-label">More</div> <div data-v-7e6dc93e="" class="label"><div data-v-7e6dc93e="" class="label-item"><div data-v-7e6dc93e="" class="label-text"><a data-v-7e6dc93e="" href="" class="label-link">Software Engineering</a> <span data-v-7e6dc93e="" class="close-btn"></span></div></div><div data-v-7e6dc93e="" class="label-item"><div data-v-7e6dc93e="" class="label-text"><a data-v-7e6dc93e="" href="" class="label-link">Quality Control</a> <span data-v-7e6dc93e="" class="close-btn"></span></div></div><div data-v-7e6dc93e="" class="label-item"><div data-v-7e6dc93e="" class="label-text"><a data-v-7e6dc93e="" href="" class="label-link">Technology Operations</a> <span data-v-7e6dc93e="" class="close-btn"></span></div></div><div data-v-7e6dc93e="" class="label-item"><div data-v-7e6dc93e="" class="label-text"><a data-v-7e6dc93e="" href="" class="label-link">Security</a> <span data-v-7e6dc93e="" class="close-btn"></span></div></div><div data-v-7e6dc93e="" class="label-item"><div data-v-7e6dc93e="" class="label-text"><a data-v-7e6dc93e="" href="" class="label-link">AI,Algorithm and Big Data</a> <span data-v-7e6dc93e="" class="close-btn"></span></div></div><div data-v-7e6dc93e="" class="label-item"><div data-v-7e6dc93e="" class="label-text"><a data-v-7e6dc93e="" href="" class="label-link">Enterprise Management</a> <span data-v-7e6dc93e="" class="close-btn"></span></div></div></div></div> <div data-v-7e6dc93e="" class="correlation-degree"><div data-v-7e6dc93e="" class="recruit-wrap recruit-margin"><!----> <div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">CSIG16-地图图像算法工程师</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">CSIG</span> |
                  <span data-v-7e6dc93e="">Beijing,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">还原现实世界：与各类技术专家一起，使用最先进的图像算法能力还原现实世界，呈现一流的数字地图服务体验；
数据挖掘：结合各类大数据源挖掘感知产品缺陷，并打造自动化修正和完善产品体验的工业能力；</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1207595915481714688" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">22989-专有云运营开发工程师（腾讯云全资子公司）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">CSIG</span> |
                  <span data-v-7e6dc93e="">Wuhan,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> 
                  <p data-v-7e6dc93e="" class="recruit-text">1. 负责腾讯专有云内部效率工具的研发和维护。
2. 负责项目交付部署相关平台工具的研发。
3. 负责DevOps相关平台工具的研发。
此岗位为腾讯集团旗下全资子公司编制岗位</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1205371242035548160" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">27141-FPS手游后台开发（深圳）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">IEG</span> |
                  <span data-v-7e6dc93e="">Shenzhen,China</span> |
                  <a href="https://www.tencent.com">Tencent</a>
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">负责手机游戏服务器逻辑功能设计编码以及运营开发工作；
负责部分服务器端的架构工作；
负责部分服务器端的性能优化工作。</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1175980467749392384" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">27141-高级游戏引擎工程师</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">IEG</span> |
                  <span data-v-7e6dc93e="">Shenzhen,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">负责游戏客户端的开发、维护，侧重于图形程序；负责客户端的性能优化； 负责新技术预研、框架搭建。</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1188635956505219072" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">27141-FPS手游客户端开发工程师（深圳）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">IEG</span> |
                  <span data-v-7e6dc93e="">Shenzhen,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">负责游戏客户端逻辑功能和核心模块的开发； 
负责对Unreal Engine进行性能优化和支持； 
负责美术、策划工具的开发。</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1154636411580715008" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">27553-腾讯音乐前端开发工程师（深圳）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">公司其他组织</span> |
                  <span data-v-7e6dc93e="">Shenzhen,China</span>
                  <a href="www.utas.edu.au">UTAS</a>
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">负责腾讯音乐企业发展部web前端开发工作，包括制定符合业务发展需要的前端方案；
搭建前端架构以及核心代码实现；
配合服务端开发共同完成项目开发任务并落地实施。</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1207569668051570688" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">27553-腾讯音乐测试工程师（深圳）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">公司其他组织</span> |
                  <span data-v-7e6dc93e="">Shenzhen,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">负责企业发展部相关系统的测试工作，包括移动端和PC端系统；
负责部门自动化测试框架的搭建；
负责相关产品自动化测试水平的提升。</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1207569654797570048" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">WXG03-小程序交易平台后台开发工程师（广州）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">WXG</span> |
                  <span data-v-7e6dc93e="">Guangzhou,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">负责微信担保交易业务的后台支持。</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1207564825035542528" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">WXG04-113 微信小游戏后台开发工程师（深圳）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">WXG</span> |
                  <span data-v-7e6dc93e="">Shenzhen,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">1. 负责微信小游戏安全策略平台建设； 
2. 完善小游戏的安全策略和模型能力，做到主动发现生态内的潜在问题；  
3. 为开发者提供便捷、高效的能力，降低游戏制作成本，繁荣小游戏生态；</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1207563634255859712" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div><div data-v-7e6dc93e="" class="recruit-list"><a data-v-7e6dc93e="" class="recruit-list-link"><h4 data-v-7e6dc93e="" class="recruit-title">WXG01-113 微信后台开发工程师（广州）</h4> <p data-v-7e6dc93e="" class="recruit-tips"><span data-v-7e6dc93e="">WXG</span> |
                  <span data-v-7e6dc93e="">Guangzhou,China</span> |
                  <span data-v-7e6dc93e="">Technology</span> |
                  <!----> <span data-v-7e6dc93e="">December 19,2019</span></p> <p data-v-7e6dc93e="" class="recruit-text">负责微信基础产品的平台和运营能力建设；
参与微信基础产品的数据平台设计和搭建；
参与微信产品核心数据的维护和监控；
参与微信基础数据服务框架的开发和维护。
</p></a> <div data-v-114c7c2f="" data-v-7e6dc93e="" class="recruit-share"><div data-v-114c7c2f="" class="recruit-content"><span data-v-114c7c2f="" class="share"></span> <span data-v-114c7c2f="" class="share-text">Share</span> <div data-v-114c7c2f="" id="share-detail" class="share-list"><div data-v-114c7c2f="" class="share-title">Share</div> <div data-v-114c7c2f="" class="close-btn"></div> <div data-v-114c7c2f="" id="1207563570045259776" class="qr-code" style="display: none;"></div> <ul data-v-114c7c2f="" class="share-gound"><li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon qq"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="javascript:;" class="share-icon wechat"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon micro-blog"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon in"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon facebook"></a></li> <li data-v-114c7c2f="" class="share-item"><a data-v-114c7c2f="" href="" target="_blank" class="share-icon twitter"></a></li></ul> <div data-v-114c7c2f="" class="link-wrapper"><div data-v-114c7c2f="" class="link-text">Link</div> <div data-v-114c7c2f="" class="link-ground"><input data-v-114c7c2f="" readonly="readonly" id="" class="link input-text"> <div data-v-114c7c2f="" class="copy">Copy link</div></div></div></div></div></div> <div data-v-7e6dc93e="" class="recruit-collection"><span data-v-7e6dc93e="" class="icon-collection"></span> <span data-v-7e6dc93e="" class="collection-text">Save</span></div></div></div></div> <!----> <div data-v-7e6dc93e="" class="page-number"><ul class="page-list"><li class="prev disabled">&nbsp;</li> <li class="page-li active"><span class="page-text">1</span></li> <!----> <li class="page-li"><span class="page-text">2</span></li><li class="page-li"><span class="page-text">3</span></li><li class="page-li"><span class="page-text">4</span></li><li class="page-li"><span class="page-text">5</span></li><li class="page-li"><span class="page-text">6</span></li> <li class="page-li more btn-quicknext"><span class="page-text more btn-quicknext">...</span></li> <li class="page-li"><span class="page-text">194</span></li> <li class="next">&nbsp;</li></ul></div></div></div>
"""

bs = BeautifulSoup(html, "lxml")
print(bs.prettify())
# Out:
# <html>
#  <body>
#   <div class="main max-center g-clr" data-v-7e6dc93e="">
#    <a href="www.utas.edu.au">
#     UTAS
#    </a>
#    <div class="search-sidebar" data-v-7e6dc93e="">
#     <div class="sidebar-title" data-v-7e6dc93e="">
#      Filter by
#     </div>
#     <div class="option-wrapper" data-v-7e6dc93e="">
#      <div class="option-item" data-v-7e6dc93e="">
#       <div class="item-text" data-v-7e6dc93e="">
#        <a class="item-link" data-v-7e6dc93e="" href="javascript:;">
#         Country/region
#        </a>
#        <div class="open-btn" data-v-7e6dc93e="">
#         <div class="vertical-btn" data-v-7e6dc93e="">
#         </div>
#         <div class="transverse-btn" data-v-7e6dc93e="">
#         </div>
#        </div>
#       </div>
#       <ul class="item-ul" data-v-7e6dc93e="" style="padding-top: 20px; display: none;">
#        <li class="item-li-box" data-v-7e6dc93e="">
#         <div class="checkbox-content" data-v-7e6dc93e="">
# ...

# %%
#get all p tags
soup = BeautifulSoup(html, 'lxml')
ps = soup.select('p')
for p in ps:
    print(p)
# Out:
# <p class="tips" data-v-7e6dc93e="" style="display: none;">Showing 76 results for ""</p>
# <p class="tips active" data-v-7e6dc93e=""> </p>
# <p class="recruit-tips" data-v-7e6dc93e=""><span data-v-7e6dc93e="">CSIG</span> |
#                   <span data-v-7e6dc93e="">Beijing,China</span> |
#                   <span data-v-7e6dc93e="">Technology</span> |
#                   <!-- --> <span data-v-7e6dc93e="">December 19,2019</span></p>
# <p class="recruit-text" data-v-7e6dc93e="">还原现实世界：与各类技术专家一起，使用最先进的图像算法能力还原现实世界，呈现一流的数字地图服务体验；
# 数据挖掘：结合各类大数据源挖掘感知产品缺陷，并打造自动化修正和完善产品体验的工业能力；</p>
# <p class="recruit-tips" data-v-7e6dc93e=""><span data-v-7e6dc93e="">CSIG</span> |
#                   <span data-v-7e6dc93e="">Wuhan,China</span> |
#                   <span data-v-7e6dc93e="">Technology</span> |
#                   <!-- --> <span data-v-7e6dc93e="">December 19,2019</span></p>
# <p class="recruit-text" data-v-7e6dc93e="">1. 负责腾讯专有云内部效率工具的研发和维护。
# 2. 负责项目交付部署相关平台工具的研发。
# 3. 负责DevOps相关平台工具的研发。
# ...

# %%
#get the third p tag
soup = BeautifulSoup(html, 'lxml')
p = soup.select('p')[3]
print(p)
# Out:
# <p class="recruit-text" data-v-7e6dc93e="">还原现实世界：与各类技术专家一起，使用最先进的图像算法能力还原现实世界，呈现一流的数字地图服务体验；
# 数据挖掘：结合各类大数据源挖掘感知产品缺陷，并打造自动化修正和完善产品体验的工业能力；</p>

# %%
ps = soup.select('.recruit-text')

for p in ps:
    print(p)
# Out:
# <p class="recruit-text" data-v-7e6dc93e="">还原现实世界：与各类技术专家一起，使用最先进的图像算法能力还原现实世界，呈现一流的数字地图服务体验；
# 数据挖掘：结合各类大数据源挖掘感知产品缺陷，并打造自动化修正和完善产品体验的工业能力；</p>
# <p class="recruit-text" data-v-7e6dc93e="">1. 负责腾讯专有云内部效率工具的研发和维护。
# 2. 负责项目交付部署相关平台工具的研发。
# 3. 负责DevOps相关平台工具的研发。
# 此岗位为腾讯集团旗下全资子公司编制岗位</p>
# <p class="recruit-text" data-v-7e6dc93e="">负责手机游戏服务器逻辑功能设计编码以及运营开发工作；
# 负责部分服务器端的架构工作；
# 负责部分服务器端的性能优化工作。</p>
# <p class="recruit-text" data-v-7e6dc93e="">负责游戏客户端的开发、维护，侧重于图形程序；负责客户端的性能优化； 负责新技术预研、框架搭建。</p>
# <p class="recruit-text" data-v-7e6dc93e="">负责游戏客户端逻辑功能和核心模块的开发；
# 负责对Unreal Engine进行性能优化和支持；
# 负责美术、策划工具的开发。</p>
# <p class="recruit-text" data-v-7e6dc93e="">负责腾讯音乐企业发展部web前端开发工作，包括制定符合业务发展需要的前端方案；
# 搭建前端架构以及核心代码实现；
# 配合服务端开发共同完成项目开发任务并落地实施。</p>
# <p class="recruit-text" data-v-7e6dc93e="">负责企业发展部相关系统的测试工作，包括移动端和PC端系统；
# 负责部门自动化测试框架的搭建；
# 负责相关产品自动化测试水平的提升。</p>
# <p class="recruit-text" data-v-7e6dc93e="">负责微信担保交易业务的后台支持。</p>
# <p class="recruit-text" data-v-7e6dc93e="">1. 负责微信小游戏安全策略平台建设；
# ...

# %%
aList = soup.select('a')

for a in aList:
    href = a['href']
    print(href)
# Out:
# www.utas.edu.au
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-fef5e7980d6d> in <module>
#       2
#       3 for a in aList:
# ----> 4     href = a['href']
#       5     print(href)
#
# /opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#     969         """tag[key] returns the value of the 'key' attribute for the tag,
#     970         and throws an exception if it's not there."""
# --> 971         return self.attrs[key]
#     972
#     973     def __iter__(self):
#
# KeyError: 'href'

# %%
ps = soup.select('p')[2:]

for p in ps:
    info = list(p.stripped_strings)
    print(info)
# Out:
# ['CSIG', '|', 'Beijing,China', '|', 'Technology', '|', 'December 19,2019']
# ['还原现实世界：与各类技术专家一起，使用最先进的图像算法能力还原现实世界，呈现一流的数字地图服务体验；\n数据挖掘：结合各类大数据源挖掘感知产品缺陷，并打造自动化修正和完善产品体验的工业能力；']
# ['CSIG', '|', 'Wuhan,China', '|', 'Technology', '|', 'December 19,2019']
# ['1. 负责腾讯专有云内部效率工具的研发和维护。\n2. 负责项目交付部署相关平台工具的研发。\n3. 负责DevOps相关平台工具的研发。\n此岗位为腾讯集团旗下全资子公司编制岗位']
# ['IEG', '|', 'Shenzhen,China', '|', 'Tencent', 'Technology', '|', 'December 19,2019']
# ['负责手机游戏服务器逻辑功能设计编码以及运营开发工作；\n负责部分服务器端的架构工作；\n负责部分服务器端的性能优化工作。']
# ['IEG', '|', 'Shenzhen,China', '|', 'Technology', '|', 'December 19,2019']
# ['负责游戏客户端的开发、维护，侧重于图形程序；负责客户端的性能优化； 负责新技术预研、框架搭建。']
# ['IEG', '|', 'Shenzhen,China', '|', 'Technology', '|', 'December 19,2019']
# ['负责游戏客户端逻辑功能和核心模块的开发； \n负责对Unreal Engine进行性能优化和支持； \n负责美术、策划工具的开发。']
# ['公司其他组织', '|', 'Shenzhen,China', 'UTAS', 'Technology', '|', 'December 19,2019']
# ['负责腾讯音乐企业发展部web前端开发工作，包括制定符合业务发展需要的前端方案；\n搭建前端架构以及核心代码实现；\n配合服务端开发共同完成项目开发任务并落地实施。']
# ...
